# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv('Pune_Housing-2.csv')

# %%
df.drop(columns=['Unnamed: 0'],axis=1,inplace=True)

# %%
df.head()
# Out:
#    bhk   locality  sqft  price_per_sqft  bath  Price_Lakhs  Build_year  Age
# 0    2  Tathawade   950            5052   2.0         48.0      2022.0  1.0
# 1    2      Ravet   965            4974   2.0         48.0      2023.0  2.0
# 2    2      Ravet   975            5128   2.0         50.0      2020.0 -1.0
# 3    3  Tathawade  1125            5511   2.0         62.0      2023.0  2.0
# 4    2      Ravet   945            5291   2.0         50.0      2022.0  1.0

# %%
df.dtypes
# Out:
# bhk                 int64
# locality           object
# sqft                int64
# price_per_sqft      int64
# bath              float64
# Price_Lakhs       float64
# Build_year        float64
# Age               float64
# dtype: object

# %%
df.shape
# Out:
# (4857, 8)

# %%
df.describe()
# Out:
#                bhk         sqft  price_per_sqft         bath  Price_Lakhs  \
# count  4857.000000  4857.000000     4857.000000  2934.000000  4857.000000
# mean      2.272802  1069.606753     8529.422689     2.200409    92.476858
# std       0.756022   594.683249     3133.866601     0.764486    70.074383
# min       1.000000   241.000000      800.000000     1.000000    11.000000
# 25%       2.000000   729.000000     6200.000000     2.000000    53.240000
# 50%       2.000000   973.000000     8022.000000     2.000000    75.000000
# 75%       3.000000  1200.000000    10303.000000     3.000000   105.000000
# max       7.000000  9500.000000    26662.000000     9.000000   900.000000
#
#         Build_year          Age
# count  4857.000000  4857.000000
# mean   2020.380482    -0.619518
# std       7.162144     7.162144
# min    1899.000000  -122.000000
# 25%    2016.000000    -5.000000
# 50%    2023.000000     2.000000
# 75%    2025.000000     4.000000
# max    2030.000000     9.000000

# %%
df.head()
# Out:
#    bhk   locality  sqft  price_per_sqft  bath  Price_Lakhs  Build_year  Age
# 0    2  Tathawade   950            5052   2.0         48.0      2022.0  1.0
# 1    2      Ravet   965            4974   2.0         48.0      2023.0  2.0
# 2    2      Ravet   975            5128   2.0         50.0      2020.0 -1.0
# 3    3  Tathawade  1125            5511   2.0         62.0      2023.0  2.0
# 4    2      Ravet   945            5291   2.0         50.0      2022.0  1.0

# %%
df.bath.value_counts()
# Out:
# bath
# 2.0    1702
# 3.0     696
# 1.0     405
# 4.0     105
# 5.0      21
# 6.0       3
# 7.0       1
# 9.0       1
# Name: count, dtype: int64

# %%
df.bhk.value_counts()
# Out:
# bhk
# 2    2629
# 3    1394
# 1     590
# 4     216
# 5      24
# 6       3
# 7       1
# Name: count, dtype: int64

# %%
df.locality.value_counts()
# Out:
# locality
# Kharadi             398
# Wagholi             331
# Tathawade           306
# Ravet               300
# Wakad               258
#                    ...
# Ajmera colony         1
# Baramati              1
# Warje Malwadi         1
# Gulab Nagar Pune      1
# Vadgaon               1
# Name: count, Length: 130, dtype: int64

# %%
df.locality.unique()
# Out:
# array(['Tathawade', 'Ravet', 'Gulab Nagar Pune', 'Dhankawadi', 'Thergaon',
#        'Bibwewadi', 'Walvekar Nagar', 'Katraj', 'Ambegaon Budruk',
#        'Parvati Darshan', 'Handewadi', 'Undri', 'Alandi', 'Nere',
#        'Hinjewadi', 'Kharadi', 'Pashan', 'Wakad', 'Mahalunge',
#        'Pune Satara Road', 'Wagholi', 'Dhayari', 'Bavdhan', 'Chinchwad',
#        'Somwar Peth', 'Bhukum', 'Hadapsar', 'Vishrantwadi', 'Fursungi',
#        'Kalewadi Pandhapur Road', 'Jambhul', 'Fursungi Gaon', 'NIBM Road',
#        'Dhanori', 'Aundh', 'Amanora Park Town', 'Wadachiwadi Road',
#        'Jambhulwadi Road', 'Mundhwa', 'Kothrud', 'Sus',
#        'NIBM Annex Mohammadwadi', 'Taljai Temple Road', 'Kondhwa',
#        'Moshi', 'Porwal Road', 'Tingre Nagar', 'Baner',
#        'Bhusari colony right', 'Gultekdi', 'Vadgaon Budruk',
#        'Uruli Kanchan', 'Lohegaon', 'Patil Nager', 'Balewadi',
#        'Bijali Nagar PimpriChinchwad', 'Punawale', 'Viman Nagar',
# ...

# %%
df.locality = df.locality.str.strip()

# %%
list1 = list(df.locality.unique())

# %%
df[df['locality'] == 'Kharadi'].price_per_sqft.median()
# Out:
# 9731.5

# %%
list2 = []
for i in list1:
    list2.append((i ,df[df['locality'] == i].price_per_sqft.mean()))

# %%
df_Region_price = pd.DataFrame(list2)

# %%
df_Region_price.sort_values(by=1,ascending=False).head()
# Out:
#                    0             1
# 95         Erandwane  23025.166667
# 115     Prabhat Road  18991.000000
# 76   Deccan Gymkhana  17773.000000
# 128      Ashok Nagar  17283.000000
# 105    Shivaji Nagar  16636.200000

# %%
fig = plt.figure() # create figure

plot1 = fig.add_subplot(1,2,1) # add subplot 1 (1 row, 2 columns, first plot)
plot2 = fig.add_subplot(1,2,2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**
sns.boxplot(x='Price_Lakhs',data=df,ax=plot1,width=0.5,color='green',fliersize=2,linewidth=1)
sns.boxplot(x='sqft',data=df,ax=plot2,width=0.5,color='green',fliersize=2,linewidth=1)



fig = plt.figure() # create figure

plot1 = fig.add_subplot(1,2,1) # add subplot 1 (1 row, 2 columns, first plot)
plot2 = fig.add_subplot(1,2,2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**
sns.boxplot(x='Age',data=df,ax=plot1,width=0.5,color='green',fliersize=2,linewidth=1)
sns.boxplot(x='price_per_sqft',data=df,ax=plot2,width=0.5,color='green',fliersize=2,linewidth=1)
# Out:
# <Axes: xlabel='price_per_sqft'>

# %%
df.columns
# Out:
# Index(['bhk', 'locality', 'sqft', 'price_per_sqft', 'bath', 'Price_Lakhs',
#        'Build_year', 'Age'],
#       dtype='object')

# %%
df=df.drop(['locality'], axis=1)

# %%
df.corr()
# Out:
#                      bhk      sqft  price_per_sqft      bath  Price_Lakhs  \
# bhk             1.000000  0.694287        0.329311  0.914766     0.699334
# sqft            0.694287  1.000000        0.068742  0.765084     0.827321
# price_per_sqft  0.329311  0.068742        1.000000  0.360996     0.549078
# bath            0.914766  0.765084        0.360996  1.000000     0.701031
# Price_Lakhs     0.699334  0.827321        0.549078  0.701031     1.000000
# Build_year      0.117018 -0.086852        0.243952  0.083608     0.041355
# Age             0.117018 -0.086852        0.243952  0.083608     0.041355
#
#                 Build_year       Age
# bhk               0.117018  0.117018
# sqft             -0.086852 -0.086852
# price_per_sqft    0.243952  0.243952
# bath              0.083608  0.083608
# Price_Lakhs       0.041355  0.041355
# Build_year        1.000000  1.000000
# Age               1.000000  1.000000

# %%
sns.heatmap(df.corr(),annot=True);

# %%
fig = plt.figure() # create figure

plot1 = fig.add_subplot(1,3,1) # add subplot 1 (1 row, 2 columns, first plot)
plot2 = fig.add_subplot(1,3,2) # add subplot 2 (1 row, 2 columns, second plot). See tip below**
plot3 = fig.add_subplot(1,3,3) # add subplot 1 (1 row, 2 columns, first plot)

df.plot(kind='scatter', x='bhk', y='Price_Lakhs', figsize=(10, 6), color='darkblue',ax=plot1) # add to subplot 1
df.plot(kind='scatter', x='bath', y='Price_Lakhs', figsize=(10, 6), color='darkblue',ax=plot2) # add to subplot 1
df.plot(kind='scatter', x='sqft', y='Price_Lakhs', figsize=(10, 6), color='darkblue',ax=plot3) # add to subplot 1
# Out:
# <Axes: xlabel='sqft', ylabel='Price_Lakhs'>

# %%
sns.pairplot(df,height=1.8);
# Out:
# /Users/sarthak/miniconda3/lib/python3.10/site-packages/seaborn/axisgrid.py:118: UserWarning: The figure layout has changed to tight
#   self._figure.tight_layout(*args, **kwargs)
